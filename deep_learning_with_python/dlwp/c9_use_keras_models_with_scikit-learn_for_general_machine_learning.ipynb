# %% [markdown]
# # C9: Use Keras Models With Scikit-Learn For General Machine Learning
#
# sklearn中提供了许多辅助建模的工具，Keras的模型也可以包装成sklearn中的model形式，然后使用sklean中的工具。本节主要介绍：
#
# * 如何把keras模型包装成sklearn的模型，以便使用sklearn中的工具
# * 如何使用sklearn交叉验证工具评价keras模型
# * 如何使用sklearn中的grid search来tune keras模型中的hyperparameters

# %% [markdown]
# ## 9.1 Overview
# ...

# %% [markdown]
# ## 9.2 把keras model封装成sklearn model
#
# 在sklearn中，model通常使用如下模式进行使用
#
# ```
# model = XXXClassifier()  # 或者model = XXXRegressor()
# model.fit(X, Y)
# y = model.predict(X)
# ```
#
# keras.wrappers.scikit_leran中提供了KerasClassifier()和KerasRegressor()两种对象来把keras中的model封装成sklearn中的model。以KerasClassifier为例，只需要把keras模型的创建方法，训练参数输入进去即可创建一个sklearn的model。[官方文档](https://keras.io/scikit-learn-api/)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier

def model_create():
    # model creator
    model = Sequential()
    model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
    model.add(Dense(8, init='uniform', activation='relu'))
    model.add(Dense(1, init='uniform', activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# wrap Keras model into a sklean model
skl_model = KerasClassifier(build_fn=model_create, nb_epoch=150, batch_size=10, verbose=0)
# Out:
# Using Theano backend.

# %% [markdown]
# ## 9.3 使用sklearn中的交叉验证工具

# %% [markdown]
# 下面使用sklean中的cross_val_score()和StratifiedKFold()两个工具来对skl_model进行交叉验证

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
import numpy as np

# set random seed
seed = 7
np.random.seed(seed)

# load data
dataset = np.loadtxt('./data_set/pima-indians-diabetes.data', delimiter=',')
X = dataset[:, 0:8]
Y = dataset[:, 8]

# evaluate model by cross validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(skl_model, X, Y, cv=kfold)

print results
print np.mean(results)
# Out:
# [ 0.77922079  0.79220779  0.76623378  0.77922077  0.75324676  0.74025974
#   0.77922078  0.71428571  0.71052632  0.75      ]
# 0.756442244065

# %% [markdown]
# 使用模型进行predict，虽然前面进行过交叉验证，但是模型还是需要训练后才能predict的

# %%
skl_model.fit(X, Y)
y = skl_model.predict(X[0:1,:])
print y
# Out:
# [[1]]

# %% [markdown]
# ## 9.4 使用sklearn中的GridSearchCV工具来选取最优模型
#
# sklearn中提供的GridSearchCV工具来选择最优的hypermeters, 同时生成最优的模型，[官方文档](http://scikit-learn.org/0.17/modules/generated/sklearn.grid_search.GridSearchCV.html)
#
#      第一步：创建一个model对象，其参数可以任意（之后由grid search 来调整）
#      第二步：设定hypermeters grid
#      第三步：创建grid对象，并fit
#      第四步：查看grid search结果

# %%
from sklearn.model_selection import GridSearchCV
import time

def create_keras_model(optimizer='adam', init='uniform'):
    model = Sequential()
    model.add(Dense(12, input_dim=8, init=init, activation='relu'))
    model.add(Dense(8, init=init, activation='relu'))
    model.add(Dense(1, init=init, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# create a model whose hypermeters is needed to be tuned again by grid search
model = KerasClassifier(build_fn=create_keras_model, verbose=0)

# set hypermeters grid
hypermeters_grid = {
    'optimizer': ['adam', 'rmsprop'],
    'init': ['glorot_uniform', 'normal', 'uniform'],
    'nb_epoch': [10, 100],
    'batch_size': [5, 10],
}

start_time = time.time()
# create a grid and fit, using 5 fold cross validation
grid = GridSearchCV(estimator=model, param_grid=hypermeters_grid, cv=5, verbose=100)
grid.fit(X, Y)
end_time = time.time()
print 'total time:', end_time - start_time

# show grid search result
print("Best: %f using %s" % (grid.best_score_, grid.best_params_))
for params, mean_score, scores in grid.grid_scores_:
    print("%f (%f) with: %r" % (scores.mean(), scores.std(), params))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5 ..
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.675325 -   0.3s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5 ..
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.642857 -   0.3s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5 ..
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.694805 -   0.2s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.4s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5 ..
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.725490 -   0.2s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    8.3s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5 ..
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.633987 -   0.3s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   10.2s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.649351 -   0.3s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   12.7s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.636364 -   0.2s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   14.2s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.681818 -   0.2s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.8s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.620915 -   0.2s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   17.5s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.647059 -   0.2s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   19.1s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.701299 -   0.2s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   25.3s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.675325 -   0.3s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   31.2s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.733766 -   0.2s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   36.9s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.745098 -   0.2s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   42.8s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.758170 -   0.2s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   48.6s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.642857 -   0.2s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   54.1s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.584416 -   0.3s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   59.5s remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.740260 -   0.2s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  1.1min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.790850 -   0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  1.2min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.699346 -   0.2s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  1.3min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=5 ..........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=5, score=0.688312 -   0.2s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  1.3min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=5 ..........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=5, score=0.681818 -   0.3s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  1.3min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=5 ..........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=5, score=0.681818 -   0.2s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  1.3min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=5 ..........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=5, score=0.718954 -   0.2s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  1.4min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=5 ..........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=5, score=0.705882 -   0.2s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  1.4min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5 .......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.668831 -   0.2s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  1.4min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5 .......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.636364 -   0.3s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.5min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5 .......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.681818 -   0.2s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  1.5min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5 .......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.745098 -   0.2s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  1.5min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5 .......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.692810 -   0.2s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.5min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=5 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=5, score=0.727273 -   0.2s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  1.6min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=5 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=5, score=0.727273 -   0.3s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  1.7min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=5 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=5, score=0.733766 -   0.2s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:  1.8min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=5 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=5, score=0.810458 -   0.2s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:  1.9min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=5 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=5, score=0.699346 -   0.2s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  2.0min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.727273 -   0.2s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  2.1min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.688312 -   0.2s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:  2.2min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.772727 -   0.2s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  2.3min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.797386 -   0.2s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  2.4min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.745098 -   0.2s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  2.5min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=5 .........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.688312 -   0.2s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  2.5min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=5 .........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.584416 -   0.2s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  2.5min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=5 .........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.688312 -   0.2s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  2.6min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=5 .........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.784314 -   0.2s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  2.6min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=5 .........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=5, score=0.660131 -   0.2s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  2.6min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5 ......
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.701299 -   0.2s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:  2.7min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5 ......
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.584416 -   0.3s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  2.7min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5 ......
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.701299 -   0.4s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  2.7min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5 ......
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.758170 -   0.2s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  2.7min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5 ......
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=5, score=0.679739 -   0.2s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.8min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=5 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.746753 -   0.2s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  2.9min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=5 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.694805 -   0.2s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  3.0min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=5 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.798701 -   0.3s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  3.1min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=5 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.777778 -   0.2s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  3.2min remaining:    0.0s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=5 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=5, score=0.764706 -   0.2s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  3.3min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.694805 -   0.3s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:  3.4min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.720779 -   0.3s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:  3.5min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.753247 -   0.2s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:  3.6min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.797386 -   0.3s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:  3.7min remaining:    0.0s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=5, score=0.725490 -   0.2s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  3.8min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.642857 -   0.3s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:  3.8min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.681818 -   0.2s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:  3.8min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.584416 -   0.3s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:  3.9min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.745098 -   0.3s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  3.9min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10 .
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.575163 -   0.3s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  3.9min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.577922 -   0.4s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  4.0min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.649351 -   0.3s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  4.0min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.623377 -   0.2s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  4.0min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.248366 -   0.2s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  4.0min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.647059 -   0.3s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  4.1min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.727273 -   0.2s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  4.1min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.415584 -   0.4s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  4.2min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.688312 -   0.2s
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:  4.3min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.745098 -   0.3s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:  4.3min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.647059 -   0.3s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  4.4min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.649351 -   0.2s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:  4.5min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.415584 -   0.3s
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:  4.5min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.636364 -   0.3s
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:  4.6min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.771242 -   0.3s
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:  4.7min remaining:    0.0s
# [CV] init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10
# [CV]  init=glorot_uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.712418 -   0.3s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  4.7min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=10 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=10, score=0.681818 -   0.2s
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:  4.8min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=10 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=10, score=0.681818 -   0.4s
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:  4.8min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=10 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=10, score=0.629870 -   0.3s
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:  4.8min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=10 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=10, score=0.751634 -   0.2s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:  4.9min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=10, batch_size=10 .........
# [CV]  init=normal, optimizer=adam, nb_epoch=10, batch_size=10, score=0.666667 -   0.3s
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:  4.9min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.662338 -   0.3s
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:  4.9min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.649351 -   0.4s
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:  5.0min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.655844 -   0.3s
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:  5.0min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.738562 -   0.3s
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:  5.0min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10 ......
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.660131 -   0.3s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:  5.0min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=10 ........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=10, score=0.688312 -   0.3s
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed:  5.1min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=10 ........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=10, score=0.694805 -   0.4s
# [Parallel(n_jobs=1)]: Done  92 out of  92 | elapsed:  5.2min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=10 ........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=10, score=0.772727 -   0.3s
# [Parallel(n_jobs=1)]: Done  93 out of  93 | elapsed:  5.3min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=10 ........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=10, score=0.816993 -   0.2s
# [Parallel(n_jobs=1)]: Done  94 out of  94 | elapsed:  5.3min remaining:    0.0s
# [CV] init=normal, optimizer=adam, nb_epoch=100, batch_size=10 ........
# [CV]  init=normal, optimizer=adam, nb_epoch=100, batch_size=10, score=0.751634 -   0.2s
# [Parallel(n_jobs=1)]: Done  95 out of  95 | elapsed:  5.4min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10 .....
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.707792 -   0.2s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed:  5.5min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10 .....
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.694805 -   0.3s
# [Parallel(n_jobs=1)]: Done  97 out of  97 | elapsed:  5.5min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10 .....
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.714286 -   0.2s
# [Parallel(n_jobs=1)]: Done  98 out of  98 | elapsed:  5.6min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10 .....
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.810458 -   0.2s
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:  5.6min remaining:    0.0s
# [CV] init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10 .....
# [CV]  init=normal, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.712418 -   0.2s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=10 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.675325 -   0.3s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=10 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.701299 -   0.4s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=10 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.694805 -   0.2s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=10 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.764706 -   0.3s
# [CV] init=uniform, optimizer=adam, nb_epoch=10, batch_size=10 ........
# [CV]  init=uniform, optimizer=adam, nb_epoch=10, batch_size=10, score=0.620915 -   0.2s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.688312 -   0.2s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.675325 -   0.3s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.668831 -   0.2s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.758170 -   0.2s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10 .....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=10, batch_size=10, score=0.633987 -   0.2s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=10 .......
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.694805 -   0.2s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=10 .......
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.701299 -   0.3s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=10 .......
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.759740 -   0.3s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=10 .......
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.803922 -   0.2s
# [CV] init=uniform, optimizer=adam, nb_epoch=100, batch_size=10 .......
# [CV]  init=uniform, optimizer=adam, nb_epoch=100, batch_size=10, score=0.725490 -   0.3s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10 ....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.727273 -   0.3s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10 ....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.694805 -   0.3s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10 ....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.759740 -   0.2s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10 ....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.790850 -   0.2s
# [CV] init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10 ....
# [CV]  init=uniform, optimizer=rmsprop, nb_epoch=100, batch_size=10, score=0.718954 -   0.2s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  6.6min finished
# total time: 400.314422131
# Best: 0.756510 using {'init': 'uniform', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 5}
# 0.674493 (0.033632) with: {'init': 'glorot_uniform', 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 5}
# 0.647101 (0.020057) with: {'init': 'glorot_uniform', 'optimizer': 'rmsprop', 'nb_epoch': 10, 'batch_size': 5}
# 0.722732 (0.030281) with: {'init': 'glorot_uniform', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 5}
# 0.691546 (0.072309) with: {'init': 'glorot_uniform', 'optimizer': 'rmsprop', 'nb_epoch': 100, 'batch_size': 5}
# 0.695357 (0.014723) with: {'init': 'normal', 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 5}
# 0.684984 (0.035524) with: {'init': 'normal', 'optimizer': 'rmsprop', 'nb_epoch': 10, 'batch_size': 5}
# 0.739623 (0.037361) with: {'init': 'normal', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 5}
# 0.746159 (0.037508) with: {'init': 'normal', 'optimizer': 'rmsprop', 'nb_epoch': 100, 'batch_size': 5}
# 0.681097 (0.064101) with: {'init': 'uniform', 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 5}
# 0.684984 (0.056622) with: {'init': 'uniform', 'optimizer': 'rmsprop', 'nb_epoch': 10, 'batch_size': 5}
# 0.756549 (0.035220) with: {'init': 'uniform', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 5}
# 0.738341 (0.034864) with: {'init': 'uniform', 'optimizer': 'rmsprop', 'nb_epoch': 100, 'batch_size': 5}
# 0.645870 (0.063125) with: {'init': 'glorot_uniform', 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 10}
# 0.549215 (0.152601) with: {'init': 'glorot_uniform', 'optimizer': 'rmsprop', 'nb_epoch': 10, 'batch_size': 10}
# 0.644665 (0.119415) with: {'init': 'glorot_uniform', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 10}
# 0.636992 (0.120737) with: {'init': 'glorot_uniform', 'optimizer': 'rmsprop', 'nb_epoch': 100, 'batch_size': 10}
# 0.682361 (0.039499) with: {'init': 'normal', 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 10}
# 0.673245 (0.032958) with: {'init': 'normal', 'optimizer': 'rmsprop', 'nb_epoch': 10, 'batch_size': 10}
# 0.744894 (0.048433) with: {'init': 'normal', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 10}
# 0.727952 (0.041810) with: {'init': 'normal', 'optimizer': 'rmsprop', 'nb_epoch': 100, 'batch_size': 10}
# 0.691410 (0.046281) with: {'init': 'uniform', 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 10}
# 0.684925 (0.040797) with: {'init': 'uniform', 'optimizer': 'rmsprop', 'nb_epoch': 10, 'batch_size': 10}
# 0.737051 (0.040455) with: {'init': 'uniform', 'optimizer': 'adam', 'nb_epoch': 100, 'batch_size': 10}
# 0.738324 (0.033493) with: {'init': 'uniform', 'optimizer': 'rmsprop', 'nb_epoch': 100, 'batch_size': 10}
# /Users/liuweijie/WorkSpace/DeepLearning/deep_learning_with_python/.env/lib/python2.7/site-packages/sklearn/model_selection/_search.py:662: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %% [markdown]
# 一个实验，以上grid_search在不同环境下的耗时如下：
#
# * pc(i7 6700k, gtx1080)
#
#         tensorflow, cpu, n_jobs=1, 2159s
#         theano, cpu, n_jobs=1, 198s
#         theano, gpu, n_jobs=1, 348s
#
# * mac(i7 2.4GHz)
#
#         theano, cpu, n_jobs=1, 400s
#         tensorflow, cpu, n_jobs=1, inifinte
#
# 在tensorflow下还无法使用gpu。可以看到，如果不能分布式计算，gpu还是来不过cpu的。tenserflow比theano慢很多。原因我也还说不清楚。
#
# n_jobs好像只能用1，其他值会有问题，好像是keras的bug。
